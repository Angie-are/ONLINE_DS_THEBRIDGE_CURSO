# %% [markdown]
# print ("Hola Mundo")

# %% [markdown]
# Hola mundo

# %% [markdown]
# ## Mis primeros pasos con Markdown...
# ...son muy buenos

# %% [markdown]
# # Cabecera 1
# ## Cabecera 2

# %% [markdown]
# ### Cabecera 3
# #### Cabecera 4
# ##### Cabecera 5
# ###### Cabecera 6

# %% [markdown]
# <h1>Header 1</h1>
# <h2>Header 2</h2>
# <h3>Header 3</h3>

# %% [markdown]
# **Texto en negrita**
# *Texto en cursiva*
# ***Texto en negrita y cursiva***

# %% [markdown]
# >Reuerda la importancia del conocimiento del negocio y del dominio
# >>Y utilizar atajos de teclado
